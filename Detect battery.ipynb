# %%
import numpy as np
import cv2
import pickle
from matplotlib import pyplot as plt
from pyzbar.pyzbar import decode
from pyzbar.pyzbar import ZBarSymbol

# %matplotlib inline

# %%
def show(img, cmap=None):
    fig, ax = plt.subplots(figsize=(16, 10))
    ax.imshow(img,cmap)

img = cv2.imread(r'C:\Users\lstyl\Desktop\CE\CV\imgs\2.png') # Modified 
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
show(img, 'gray')

# %%
imgsub = img[600:,350:1350] # Modified
imgflt = cv2.bilateralFilter(imgsub,9,75,75)
show(imgflt,'gray')
show(imgflt>200, 'gray') # Modified
# Find all true points indices
ind = np.argwhere(imgflt>200) # Modified
indf = np.flip(ind,1)

# %%
# OBB------------------------------------------------------------------------------
ca = np.cov(indf,y = None,rowvar = 0,bias = 0)

v, vect = np.linalg.eig(ca)
idx = v.argsort()[::-1]
vect = vect[:,idx]
tvect = np.transpose(vect)

# use the inverse of the eigenvectors as a rotation matrix and rotate the points so they align with the x and y axes
ar = np.dot(indf,np.linalg.inv(tvect))

# get the minimum and maximum x and y 
mina = np.min(ar,axis=0)
maxa = np.max(ar,axis=0)
diff = (maxa - mina)*0.5

# the center is just half way between the min and max xy
center = mina + diff

# get the 4 corners by subtracting and adding half the bounding boxes height and width to the center
corners = np.array([center+[-diff[0],-diff[1]],center+[diff[0],-diff[1]],center+[diff[0],diff[1]],center+[-diff[0],diff[1]],center+[-diff[0],-diff[1]]])

# use the the eigenvectors as a rotation matrix and rotate the corners and the centerback
corners = np.dot(corners,tvect)
center = np.dot(center,tvect)
center[0] = center[0]+350
center[1] = center[1]+600

# Polynomial fitting
delta = tvect[0][1] / tvect[0][0]

sum1 = 0 # Sum values along the vector 
sum2 = 0
for i in ind:
    if tvect[0].dot(i-center) < 0:
        sum1 = sum1 + img[i[0], i[1]]
    else:
        sum2 = sum2 + img[i[0], i[1]]
cb_orient = tvect[0] if sum1 > sum2 else -tvect[0]
cb_center = center

show(img,'gray')
plt.scatter([cb_center[0]],[cb_center[1]])    
#plt.plot(corners[:,0],corners[:,1],'-')
plt.axis('equal')
plt.quiver(cb_center[0], cb_center[1], cb_orient[0], cb_orient[1], scale_units=None, angles='xy', color='blue', width=0.005)
plt.show()
print(cb_orient)
cb_center[0] = (cb_center[0] - 1920/2)*12.8/1920*558/5
cb_center[1] = -(cb_center[1] - 1080/2)*12.8/1920*558/5
# Out:
# [0.97374103 0.22765852]
